# %% [markdown]
# ***#CHECKPOINT 1***

# %% [markdown]
# #PRAKTIKUM ANALITIK DAN VISUALISASI DATA

# %% [markdown]
# ##Calories Burnt Prediction
# ###Mohamad Ariel Saputra D Loi / 2409116087

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/drive/MyDrive/Analitik dan visualisasi data/calories.csv")

# %%
data
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
#        Calories
# ...

# %% [markdown]
# ##STUDI KASUS

# %% [markdown]
# 1. Analisis Struktur Data dan type data
# 2. Tentukan Berapa Jumlah Laki Laki dan Perempuan

# %% [markdown]
# ###NOMOR 1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  object
#  2   Age         15000 non-null  int64
#  3   Height      15000 non-null  float64
#  4   Weight      15000 non-null  float64
#  5   Duration    15000 non-null  float64
#  6   Heart_Rate  15000 non-null  float64
#  7   Body_Temp   15000 non-null  float64
#  8   Calories    15000 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 1.0+ MB

# %%
data.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
data.tail()
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
#        Calories
# 14995      45.0
# 14996      23.0
# 14997      75.0
# 14998      11.0
# 14999      98.0

# %%
data.shape
# Out:
# (15000, 9)

# %%
data.dtypes
# Out:
# User_ID         int64
# Gender         object
# Age             int64
# Height        float64
# Weight        float64
# Duration      float64
# Heart_Rate    float64
# Body_Temp     float64
# Calories      float64
# dtype: object

# %% [markdown]
# ###NOMOR 2

# %%
jumlah_gender = data['Gender'].value_counts()

# Menampilkan hasil
print(jumlah_gender)
# Out:
# Gender
# female    7553
# male      7447
# Name: count, dtype: int64

# %% [markdown]
# # BUSINESS UNDERSTANDING

# %% [markdown]
# ##Business Objective

# %% [markdown]
# ####Tujuan utama dari proyek ini adalah untuk mengembangkan model prediksi yang dapat memperkirakan jumlah kalori yang terbakar berdasarkan faktor fisiologis (usia, berat badan, tinggi badan) dan parameter aktivitas fisik (durasi, detak jantung, suhu tubuh)

# %% [markdown]
# ##Assess Situation

# %% [markdown]
# ####Kualitas Data: Perlu dilakukan pembersihan data untuk mengatasi missing values, outliers, atau kesalahan data.
#
# ####Keakuratan Model: Model prediksi harus memiliki tingkat error yang rendah agar dapat diandalkan.
#
# ####Aplikasi Hasil: Model dapat digunakan untuk mengembangkan fitur dalam aplikasi kebugaran atau alat pelatihan atlet.
#
# ####Kendala Teknis: Memilih algoritma machine learning yang tepat agar model dapat berjalan efisien dalam sistem produksi.

# %% [markdown]
# ##Data Mining Goals

# %% [markdown]
# ####Menganalisis keterkaitan antara variabel-variabel seperti usia, berat badan, durasi latihan, dan kalori yang terbakar.Membangun model machine learning yang dapat secara akurat memprediksi jumlah kalori yang terbakar berdasarkan data yang diberikan.Menghasilkan insight yang actionable untuk pengguna aplikasi kebugaran atau pelatih dalam merancang latihan yang sesuai dengan kebutuhan individu.

# %% [markdown]
# ##Project Plan

# %% [markdown]
# #####Proyek ini bertujuan untuk mengembangkan model prediksi jumlah kalori yang terbakar berdasarkan faktor fisiologis dan parameter aktivitas fisik dengan menggunakan dataset Calories Burnt Prediction dari Kaggle. Kami akan mengikuti pendekatan CRISP-DM yang mencakup pemahaman bisnis, eksplorasi data, pembersihan data, pengembangan model machine learning, evaluasi performa, serta implementasi dalam aplikasi kebugaran

# %% [markdown]
# ***#CHECKPOINT 2***

# %% [markdown]
# #Data Understanding

# %%
data
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
#        Calories
# ...

# %% [markdown]
# ##Memeriksa Struktur Data

# %% [markdown]
# Info ringkas dari tabel

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  object
#  2   Age         15000 non-null  int64
#  3   Height      15000 non-null  float64
#  4   Weight      15000 non-null  float64
#  5   Duration    15000 non-null  float64
#  6   Heart_Rate  15000 non-null  float64
#  7   Body_Temp   15000 non-null  float64
#  8   Calories    15000 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 1.0+ MB

# %% [markdown]
# Pemeriksaan tipe data

# %%
data.dtypes
# Out:
# User_ID         int64
# Gender         object
# Age             int64
# Height        float64
# Weight        float64
# Duration      float64
# Heart_Rate    float64
# Body_Temp     float64
# Calories      float64
# dtype: object

# %% [markdown]
# Memeriksa jumlah baris dan kolom

# %%
data.shape
# Out:
# (15000, 9)

# %% [markdown]
# Pengecekan 5 baris pertama dari tabel

# %%
data.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %% [markdown]
# Pengecekan 5 baris terakhir dari tabel

# %%
data.tail()
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
#        Calories
# 14995      45.0
# 14996      23.0
# 14997      75.0
# 14998      11.0
# 14999      98.0

# %% [markdown]
# ##Pengecekan statistik deskriptif

# %% [markdown]
# Memerika statistik ringkasan dari tabel

# %%
data.describe()
# Out:
#             User_ID           Age        Height        Weight      Duration  \
# count  1.500000e+04  15000.000000  15000.000000  15000.000000  15000.000000
# mean   1.497736e+07     42.789800    174.465133     74.966867     15.530600
# std    2.872851e+06     16.980264     14.258114     15.035657      8.319203
# min    1.000116e+07     20.000000    123.000000     36.000000      1.000000
# 25%    1.247419e+07     28.000000    164.000000     63.000000      8.000000
# 50%    1.499728e+07     39.000000    175.000000     74.000000     16.000000
# 75%    1.744928e+07     56.000000    185.000000     87.000000     23.000000
# max    1.999965e+07     79.000000    222.000000    132.000000     30.000000
#
#          Heart_Rate     Body_Temp      Calories
# count  15000.000000  15000.000000  15000.000000
# mean      95.518533     40.025453     89.539533
# std        9.583328      0.779230     62.456978
# min       67.000000     37.100000      1.000000
# ...

# %% [markdown]
# Menghitung jumlah kemunculan nilai unik dalam kolom Calories

# %%
data.value_counts("Calories")
# Out:
# Calories
# 7.0      161
# 13.0     142
# 12.0     137
# 11.0     137
# 17.0     136
#         ...
# 272.0      1
# 258.0      1
# 269.0      1
# 253.0      1
# 314.0      1
# Name: count, Length: 277, dtype: int64

# %% [markdown]
# Menghitung korelasi antar kolom numerik

# %%
data.corr(numeric_only=True)
# Out:
#              User_ID       Age    Height    Weight  Duration  Heart_Rate  \
# User_ID     1.000000 -0.001827 -0.013520 -0.011603 -0.002751   -0.000457
# Age        -0.001827  1.000000  0.009554  0.090094  0.013247    0.010482
# Height     -0.013520  0.009554  1.000000  0.958451 -0.004625    0.000528
# Weight     -0.011603  0.090094  0.958451  1.000000 -0.001884    0.004311
# Duration   -0.002751  0.013247 -0.004625 -0.001884  1.000000    0.852869
# Heart_Rate -0.000457  0.010482  0.000528  0.004311  0.852869    1.000000
# Body_Temp   0.000923  0.013175  0.001200  0.004095  0.903167    0.771529
# Calories   -0.001661  0.154395  0.017537  0.035481  0.955421    0.897882
#
#             Body_Temp  Calories
# User_ID      0.000923 -0.001661
# Age          0.013175  0.154395
# Height       0.001200  0.017537
# Weight       0.004095  0.035481
# Duration     0.903167  0.955421
# Heart_Rate   0.771529  0.897882
# Body_Temp    1.000000  0.824558
# Calories     0.824558  1.000000

# %% [markdown]
# #Data Preparation

# %%
data
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
#        Calories
# ...

# %% [markdown]
# Pengecekan Missing Values

# %%
print((data.isna().sum() / len(data)) * 100)
# Out:
# User_ID       0.0
# Gender        0.0
# Age           0.0
# Height        0.0
# Weight        0.0
# Duration      0.0
# Heart_Rate    0.0
# Body_Temp     0.0
# Calories      0.0
# dtype: float64

# %% [markdown]
# Pengecekan data dalam tabel yang duplicate

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [User_ID, Gender, Age, Height, Weight, Duration, Heart_Rate, Body_Temp, Calories]
# Index: []

# %% [markdown]
# Pengecekan Outliers

# %%
results = []

cols = data.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = data[col].quantile(0.25)
  q3 = data[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5 * iqr
  upper_bound = q3 + 1.5 * iqr
  outliers = data[(data[col] < lower_bound) | (data[col] > upper_bound)]
  percent_outliers = (len(outliers) / len(data)) * 100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})


results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)


display(results_df)
# Out:
# Kolom       Persentase Outliers
# User_ID                0.000000
# Age                    0.000000
# Height                 0.093333
# Weight                 0.040000
# Duration               0.000000
# Heart_Rate             0.006667
# Body_Temp              2.460000
# Calories               0.026667

# %%
data.dtypes
# Out:
# User_ID         int64
# Gender         object
# Age             int64
# Height        float64
# Weight        float64
# Duration      float64
# Heart_Rate    float64
# Body_Temp     float64
# Calories      float64
# dtype: object

# %% [markdown]
# Konsisten Value tidak ada,

# %% [markdown]
# Pengecekan konsisten values (membuat umur secara ber urut

# %%
('Tidak ada yang tidak konsisten')

# %% [markdown]
# Melakukan penangan di outliers

# %%
columns_to_impute = ["Body_Temp"]

for col in columns_to_impute:
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    data.loc[:, col] = data[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# Pengecekan ulang untuk bagian outliers(body_temp)

# %%
results = []

cols = data.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = data[col].quantile(0.25)
  q3 = data[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5 * iqr
  upper_bound = q3 + 1.5 * iqr
  outliers = data[(data[col] < lower_bound) | (data[col] > upper_bound)]
  percent_outliers = (len(outliers) / len(data)) * 100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom       Persentase Outliers
# User_ID                0.000000
# Age                    0.000000
# Height                 0.093333
# Weight                 0.040000
# Duration               0.000000
# Heart_Rate             0.006667
# Body_Temp              0.000000
# Calories               0.026667

# %% [markdown]
# #Construct Data

# %% [markdown]
# Penambahan Colum

# %%
data["Rasio_Age_heartrate"] = data["Age"] / data["Heart_Rate"]
data
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
# ...

# %% [markdown]
# #Data Reduction

# %% [markdown]
# pengurangan colum yang tidak relevan

# %%
dr = data.drop('Duration', axis=1)
data
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
# ...

# %% [markdown]
# ***#CHECKPOINT 3***

# %% [markdown]
# ##VISUALISASI DATA MATPLOTLIB & SEABORN

# %% [markdown]
# kita akan tammpilkan dulu dalam visualisasi data. karena datanya banyak jadi lebih relevan jika memakai bar chart.

# %%
# Bar Chart (Matplotlib): Heart Rate per Umur(Age)
plt.figure(figsize=(16, 8))
data.groupby('Age')['Heart_Rate'].mean().plot(kind='bar', color='skyblue')
plt.title('Heart Rate per Umurnya')
plt.xlabel('Age')
plt.ylabel('Heart_Rate')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##Insight dari Visualisasi Data di Atas
# Distribusi Rata-rata Heart Rate Berdasarkan Usia
#
# Grafik menunjukkan bahwa rata-rata Heart Rate untuk setiap usia relatif stabil dan tidak banyak bervariasi.
# Tidak ada pola yang jelas mengenai peningkatan atau penurunan Heart Rate seiring bertambahnya usia.
# Masalah pada Visualisasi
#
# Terlalu banyak kategori usia pada sumbu X, sehingga label usia menjadi sulit dibaca dan membingungkan.
# Rentang usia terlalu detail (satu per satu), lebih baik jika dikelompokkan dalam interval tertentu (misalnya 20-30, 30-40, dst.).

# %% [markdown]
# Karena di Studikasus Bussines Understanding kemaren menentukan jumlah laki laki dan perempuan

# %% [markdown]
# ##Tindakan yang bisa di lakukan
# Perbaiki Visualisasi agar Lebih Mudah Dibaca
# Solusi: Kelompokkan usia dalam interval tertentu (misalnya 10 tahun per grup) menggunakan pd.cut().

# %%
# Pie Chart (Matplotlib : menentukan jumlah antara laki laki dan perempuan
plt.figure(figsize=(6, 6))
plt.pie(data['Gender'].value_counts(), labels=data['Gender'].value_counts().index, autopct='%1.1f%%', colors=['lightcoral', 'lightblue', 'lightgreen', 'gold'])
plt.title('Jumlah laki2 dan Perempuan')
plt.show()

# %% [markdown]
# ##Insight dari Visualisasi Data di Atas
# Distribusi Gender yang Seimbang
#
# Grafik pie chart menunjukkan bahwa jumlah laki-laki (49.6%) dan perempuan (50.4%) hampir seimbang dalam dataset ini.
# Perbedaan jumlah antara kedua gender sangat kecil (sekitar 0.8%), sehingga analisis tidak akan terlalu bias terhadap satu gender tertentu.
# Validasi Data
#
# Proporsi gender yang seimbang menunjukkan bahwa dataset ini cocok untuk analisis yang melibatkan perbandingan gender tanpa khawatir ada bias berat ke salah satu kelompok.
# Namun, penting untuk memeriksa apakah dataset ini benar-benar representatif dari populasi sebenarnya atau hanya sampel kecil yang kebetulan seimbang.

# %% [markdown]
# ##Tindakan yang Dapat Dilakukan
# 1.Analisis Perbandingan Berdasarkan Gender
# Perbedaan Heart Rate antara Laki-laki dan Perempuan
#
# Lakukan analisis lebih lanjut apakah ada perbedaan signifikan dalam Heart Rate berdasarkan gender.
# Gunakan visualisasi tambahan seperti boxplot untuk melihat distribusi Heart Rate pada setiap gender.

# %%
# Histogram (Seaborn)
plt.figure(figsize=(8, 5))
sns.histplot(data['Calories'], bins=20, kde=True, color='blue')
plt.title('Calories')
plt.xlabel('Calories')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# ##Insight dari Visualisasi Data di Atas
# Distribusi Tidak Simetris (Positively Skewed / Right Skewed)
#
# Histogram menunjukkan bahwa distribusi durasi kunjungan cenderung miring ke kanan.
# Sebagian besar kunjungan terjadi dalam rentang waktu lebih singkat, sedangkan kunjungan dengan durasi yang lebih lama semakin jarang terjadi.
# Mayoritas Durasi Kunjungan di Bawah 100 Menit
#
# Sebagian besar pengguna menghabiskan kurang dari 100 menit dalam kunjungan mereka, dengan puncak tertinggi sekitar 20-50 menit.
# Kunjungan yang lebih lama dari 200 menit jarang terjadi, tetapi masih ada beberapa outlier yang menghabiskan lebih dari 250 menit.
# Distribusi Mengikuti Pola Eksponensial
#
# Semakin lama durasi kunjungan, semakin rendah frekuensinya, menunjukkan kemungkinan adanya batas waktu alami atau penurunan minat setelah waktu tertentu.
# Pola ini sering terjadi dalam aktivitas seperti sesi olahraga, durasi belanja, atau waktu yang dihabiskan di suatu tempat.

# %% [markdown]
# ##Tindakan yang Dapat Dilakukan
# 1.Analisis Segmentasi Pengguna Berdasarkan Durasi Kunjungan
# Kelompokkan pengguna berdasarkan durasi kunjungan untuk memahami kebiasaan mereka.
# Pendek (0-50 menit): Pengguna yang hanya melakukan aktivitas singkat.
# Sedang (50-150 menit): Pengguna dengan interaksi yang lebih lama.
# Panjang (>150 menit): Pengguna yang sangat aktif atau mungkin pekerja tetap di lokasi tersebut.
# Analisis lebih lanjut: Apakah pengguna dengan kunjungan lebih lama memiliki kebiasaan atau preferensi khusus?

# %%
# Scatter Plot (Matplotlib): Heart Rate vs Age
plt.figure(figsize=(8, 5))
plt.scatter(data['Age'], data['Heart_Rate'], c='blue', alpha=0.1)
plt.title('AGE VS HEART RATE')
plt.xlabel('AGE')
plt.ylabel('HEART RATE')
plt.show()

# %% [markdown]
# ##insight dari Visualisasi Scatter Plot (Heart Rate vs Age)
# Pola Sebaran Heart Rate Terhadap Usia
#
# Heart rate (detak jantung) tersebar cukup luas di berbagai rentang usia.
# Tidak ada pola yang jelas atau hubungan linier langsung antara usia dan heart rate.
# Variasi detak jantung tinggi di semua usia, tetapi tetap berada dalam rentang normal (sekitar 70-120 bpm).
# Distribusi Heart Rate pada Kelompok Usia yang Berbeda
#
# Pada usia muda (20-40 tahun), heart rate cenderung lebih bervariasi tetapi tetap dalam kisaran normal.
# Pada usia lebih tua (60-80 tahun), heart rate masih memiliki variasi yang tinggi, dengan beberapa individu memiliki heart rate yang lebih tinggi dari rata-rata.
# Outlier Potensial
#
# Beberapa titik menunjukkan heart rate lebih dari 120 bpm, yang mungkin merupakan individu dengan kondisi medis tertentu atau dalam kondisi stres/latihan berat.
# Heart rate yang terlalu rendah

# %% [markdown]
# ##Tindakan yang Dapat Dilakukan
# Analisis Hubungan Lebih Lanjut
#
# Gunakan regresi atau korelasi untuk melihat apakah ada hubungan signifikan antara usia dan heart rate.
# Pisahkan analisis berdasarkan kategori aktivitas fisik atau kondisi kesehatan pengguna.
# Identifikasi Outlier dan Anomali
#
# Lakukan investigasi terhadap individu dengan heart rate sangat tinggi atau sangat rendah.
# Periksa apakah individu tersebut memiliki riwayat medis khusus yang bisa menjelaskan anomali ini.
# Segmentasi Usia dan Heart Rate
#
# Buat kelompok berdasarkan rentang usia tertentu untuk memahami bagaimana heart rate berubah dengan bertambahnya usia.
# Analisis lebih lanjut untuk melihat apakah kelompok tertentu memiliki risiko lebih tinggi terhadap gangguan jantung.
# Aplikasi dalam Kesehatan dan Kebugaran
#
# Data ini bisa digunakan untuk mengembangkan rekomendasi kesehatan berbasis usia.
# Jika ini adalah data dari wearable device atau fitness tracker, insight ini bisa digunakan untuk memberikan saran personalisasi mengenai target heart rate untuk latihan yang optimal.
